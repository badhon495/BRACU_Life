# %%
# 1244- Sort by Length
# Accepted

n = int(input())
l1 = []
temp = 0
new = ""

for i in range(n):
    for j in str(input()).split(" "):
        l1.append(j)

    for k in range(len(l1)):

        for j in range(0, len(l1)-k-1):
            if len(l1[j+1]) > len(l1[j]):
                l1[j+1],l1[j] = l1[j],l1[j+1]

    for m in range(len(l1)):
        if m < len(l1) - 1:
            print(f"{l1[m]}", end= " ")
        elif m == len(l1) - 1:
            print(l1[m])

    
    u_input = 0
    l1 = []
# Out:
# 2
# sj a sa df r e w f d s a v c x z sd fd
# sj sa df sd fd a r e w f d s a v c x z
# Top Coder comp Wedn at midnight
# midnight Coder comp Wedn Top at

# %%
# 2508 - Fortune Teller
# Accepted

while True:
    try:
        name = input()
        count = 0
        count1 = 0
        count2 = 0
        for i in name:
            j = i.upper()
            if j in ["A", 'J', 'S']:
                count += 1
            if j in ["B", 'K', 'T']:
                count += 2
            if j in ["C", 'L', 'U']:
                count += 3
            if j in ["D", 'M', 'V']:
                count += 4
            if j in ["E", 'N', 'W']:
                count += 5
            if j in ["F", 'O', 'X']:
                count += 6
            if j in ["G", 'P', 'Y']:
                count += 7
            if j in ["H", 'Q', 'Z']:
                count += 8
            if j in ["I", 'R']:
                count += 9

        for k in str(count):
            count1 += int(k)

        for m in str(count1):
            count2 += int(m)

        print(count2)

    except:
        break

# %%
# 2539 - High Five
# Runtime error

n = int(input())
standing = input()
count = 0
l1 = []
rev_standing = standing[::-1]

for i in rev_standing.split(" "):
    l1.append(int(i))

for j in range(1, n):
    count += abs(int(l1.index(j)))
    l1.remove(j)

print(count)

# %%
# 2534 - General Exam
# Accepted

while True:
    try:
        d, n = input().split(" ")

        l1 = []
        l2 = []

        for i in range(int(d)):
            u_input = int(input())
            l1.append(u_input)
        for j in range(int(n)):
            range_input = int(input())
            l2.append(range_input)

        sorted_l1 = sorted(l1, reverse=True)

        for k in l2:
            print(sorted_l1[k - 1])

    except:
        break

# %%
# 2592 - VaiNaSort
# Accepted

while True:
    n = int(input())
    count = 0
    if n == 0:
        break

    else:
        while True:
            u_input = input()
            count += 1
            l1 = []
            l2 = []

            for i in range(1, n + 1):
                l2.append(i)

            for i in u_input.split(" "):
                l1.append(int(i))

            if l1 == l2:
                print(count)
                break

# %%
# 1259 - Even and Odd
# Accepted

n = int(input())
even_list = []
odd_list = []


for i in range(n):
    u_input = int(input())
    if u_input % 2 ==0:
        even_list.append(u_input)
    else:
        odd_list.append(u_input)
main_list = sorted(even_list) + sorted(odd_list, reverse=True)
for i in main_list:
    print(i, end='\n')

# %%
# 2312 - Medal Table
# Accepted

def sort(l):
    for i in range(len(l)):
        maxIndex = i
        for j in range(i + 1, len(l)):
            if l[maxIndex][1] < l[j][1]:
                maxIndex = j
            elif l[maxIndex][1] == l[j][1]:
                if l[maxIndex][2] < l[j][2]:
                    maxIndex = j
                elif l[maxIndex][2] == l[j][2]:
                    if l[maxIndex][0] > l[j][0]:
                        maxIndex = j
        l[maxIndex], l[i] = l[i], l[maxIndex]


def store():
    global n, g
    for i in range(n):
        x = input().split()
        if int(x[1]) not in g:
            g[int(x[1])] = [[x[0], int(x[2]), int(x[3])]]
        else:
            g[int(x[1])].append([x[0], int(x[2]), int(x[3])])
            sort(g[int(x[1])])


def printTable():
    global g
    for k in sorted(g, reverse=True):
        v = g[k]
        for i in range(len(v)):
            print(f"{v[i][0]} {k} {v[i][1]} {v[i][2]}")


n = int(input())
g = {}
store()
printTable()

# %%
# 2633 - Barbecue at Yuri’s
# Accepted

while True:
    try:
        n = int(input())
        l1 = []
        l2 = []

        for i in range(n):
            x, y = str(input()).split(" ")
            l1.append(x)
            l2.append(int(y))

        for i in range(n):
            min_index = i
            for j in range(i + 1, n):
                if l2[j] < l2[min_index]:
                    min_index = j
            l2[min_index], l2[i] = l2[i], l2[min_index]
            l1[min_index], l1[i] = l1[i], l1[min_index]

        print(*l1, sep=" ")

    except:
        break

# %%
# 2137-The Library of Mr. Severino
# Accepted

while True:
    try:
        n = int(input())
        list1 = []

        for i in range(n):
            u_input = int(input())
            list1.append(u_input)

        for j in sorted(list1):
            if len(str(j)) == 4:
                print(j)
            elif len(str(j)) == 3:
                print("0" + str(j))
            elif len(str(j)) == 2:
                print("00" + str(j))
            elif len(str(j)) == 1:
                print("000" + str(j))
    except:
        break

# %%
# 3103 - Lucky Number
# Accepted

n = int(input())

for i in range(n):
  zeros = ""
  nums = ""
  main = ""
  lucky = ""
  u_input = input()
  
  for j in sorted(u_input.strip()):
      if j == "0":
          zeros += j
      else:
          nums += j
  if zeros !="":
    main = nums[0:1] + zeros + nums[1:len(str(u_input))]
  else:
    main = nums
  print(int(main))
# Out:
# 3
# 548451
# 144558
# 95480009694
# 40004568999
# 51809580050
# 10000555889

# %%
# 1120 - Contract Revision
# Accepted

while True:
    try:
        u_input = str(input())
        out = str()

        d, n = u_input.split(" ")

        for i in n:
            if i == d:
                continue
            else:
                out += i

        if int(n) == 0:
            print(int(" "))
        elif out == "":
            print(0)
        else:
            print(int(out))

    except:
        break

# %%
# 1168 - LED
# Accepted

n = int(input())
count = 0

for i in range(n):
    u_input = str(input())
    for j in u_input:
        if j == "1":
            count += 2
        elif j == "2":
            count += 5
        elif j == "2":
            count += 5
        elif j == "3":
            count += 5
        elif j == "4":
            count += 4
        elif j == "5":
            count += 5
        elif j == "6":
            count += 6
        elif j == "7":
            count += 3
        elif j == "8":
            count += 7
        elif j == "9":
            count += 6
        elif j == "0":
            count += 6
    print(f'{count} leds')
    count = 0

# %%
# 1234 - Dancing Sentence
# Accepted

while True:
    try:
        u_input = str(input())
        out = str()
        count = 0

        for j in u_input:
            if j == " ":
                out += j
            else:
                count += 1
                if count % 2 == 0:
                    out += j.lower()
                else:
                    out += j.upper()

        print(out)

    except:
        break

# %%
#1238 - Combiner
#Accepted

n = int(input())
new_word = ""
temp = 0

for i in range(n):
    u_input = input()
    x, y = u_input.split(" ")

    if len(x) <= len(y):
        for j in range(len(y)):
            new_word += x[j:j+1]+y[j:j+1]
            temp = j
        new_word += y[temp+1:len(y)]

    else:
        for j in range(len(x)):
            new_word += x[j:j+1]+y[j:j+1]
            temp = j
        new_word += x[temp+1:len(x)]
    print(new_word)
    new_word = ""
    temp = 0

# %%
# 1287- Friendly Int Parser
# Accepted

while True:
  try:
      f = True
      user_input = input().replace("O","0").replace("o","0").replace("l","1").replace(",","").replace(" ","")
      if len(user_input)!=0:
        for i in user_input:
          if 48<=ord(i)<=57:
            continue
          else:
            f = False
            break
        if f == False or int(user_input) > 2147483647:
          print("error")
        else:
          print(int(user_input))
      else:
        print("error")
            

  except EOFError:
        break
# Out:
# error
# error
# error
# error
# error
# 0
# 0
